# %%
import tensorflow as tf
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time

print(tf.__version__)
# Out:
# 2.15.0

# %%
train_path = "Radiography_Data/train"
valid_path = "Radiography_Data/valid"

# %%
train_batches = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255).flow_from_directory(directory=train_path, batch_size=64)

valid_batches = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255).flow_from_directory(directory=valid_path, batch_size=64)

test_batchesV = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255).flow_from_directory(directory=valid_path, batch_size=64, shuffle=False)

test_batchesT = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255).flow_from_directory(directory=train_path, batch_size=64, shuffle=False)
# Out:
# Found 14814 images belonging to 4 classes.
# Found 6351 images belonging to 4 classes.
# Found 6351 images belonging to 4 classes.
# Found 14814 images belonging to 4 classes.

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
mobile.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 32)      128
#  on)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 112, 112, 32)      288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 112, 112, 32)      128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormali  (None, 112, 112, 64)      256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D  (None, 56, 56, 64)        576
#  )
#
# ...

# %%
X = mobile.layers[-2].output
X = tf.keras.layers.Dense(units=1024, activation='relu')(X)
X = tf.keras.layers.Dense(units=512, activation='relu')(X)
output = tf.keras.layers.Dense(units=4, activation='softmax')(X)

# %%
model2 = tf.keras.models.Model(inputs = mobile.input, outputs=output)

# %%
model2.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 32)      128
#  on)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 112, 112, 32)      288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 112, 112, 32)      128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormali  (None, 112, 112, 64)      256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D  (None, 56, 56, 64)        576
#  )
#
#  conv_dw_2_bn (BatchNormali  (None, 56, 56, 64)        256
# ...

# %%
for layer in model2.layers[:-5]:
    layer.trainable = False

# %%
model2.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 32)      128
#  on)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 112, 112, 32)      288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 112, 112, 32)      128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormali  (None, 112, 112, 64)      256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D  (None, 56, 56, 64)        576
#  )
#
#  conv_dw_2_bn (BatchNormali  (None, 56, 56, 64)        256
# ...

# %%
model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
timeVal = time.time()
history = model2.fit(x=train_batches, validation_data=valid_batches, epochs=20, verbose=1)
print(time.time() - timeVal)
# Out:
# Epoch 1/20
# 2024-05-01 16:01:00.961686: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-05-01 16:01:04.234019: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-05-01 16:01:04.395230: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-01 16:01:13.349898: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-01 16:01:18.100428: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f3bf8772850 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
test_labelsV = test_batchesV.classes

# %%
predictions = model2.predict(x=test_batchesV, verbose=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(y_true=test_labelsV, y_pred=predictions.argmax(axis=1))

# %%
test_batchesV.class_indices
# Out:
# {'COVID': 0, 'Lung_Opacity': 1, 'Normal': 2, 'Viral Pneumonia': 3}

# %%
cm_plot_labels = ['COVID','Lung_Opacity','Normal','Viral Pneumoni']

# %%
import itertools

plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(cm_plot_labels))
plt.xticks(tick_marks, cm_plot_labels, rotation=45)
plt.yticks(tick_marks, cm_plot_labels)

thresh = cm.max()/2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
            horizontalalignment='center',
            color='white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, -46.26993134838366, 'Predicted label')

# %%
print('Accuarcy',accuracy_score(test_labelsV, predictions.argmax(axis=1)))
print('f1_score',f1_score(test_labelsV, predictions.argmax(axis=1), average='macro'))
print('Precision',precision_score(test_labelsV, predictions.argmax(axis=1), average='macro'))
print('Recall',recall_score(test_labelsV, predictions.argmax(axis=1), average='macro'))
# Out:
# Accuarcy 0.8781294284364667
# f1_score 0.8883741274931456
# Precision 0.9074978264545966
# Recall 0.8727728044375648

# %%
test_labelsV
# Out:
# array([0, 0, 0, ..., 3, 3, 3], dtype=int32)

# %%
predictions.argmax(axis=1)
# Out:
# array([0, 0, 0, ..., 3, 3, 3])

# %%
train_labels = test_batchesT.classes

# %%
predictionsT = model2.predict(x=test_batchesT, verbose=0)

# %%
print('Accuarcy',accuracy_score(train_labels, predictionsT.argmax(axis=1)))
print('f1_score',f1_score(train_labels, predictionsT.argmax(axis=1), average='macro'))
print('Precision',precision_score(train_labels, predictionsT.argmax(axis=1), average='macro'))
print('Recall',recall_score(train_labels, predictionsT.argmax(axis=1), average='macro'))
# Out:
# Accuarcy 0.9836641015255839
# f1_score 0.9859197489041827
# Precision 0.9861642141570999
# Recall 0.9860236540527452
